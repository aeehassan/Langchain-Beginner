# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="llama3.2:3b")

# %%
response = model.invoke("Explain quantum mechanics in one sentence.")
print(response.content)
# Out:
# Quantum mechanics is a branch of physics that describes the behavior of matter and energy at an atomic and subatomic level, where particles can exist in multiple states and locations simultaneously, governed by probabilistic principles rather than definite positions or trajectories.
